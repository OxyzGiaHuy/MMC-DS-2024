# %% [markdown]
# # Tổng quan dự án

# %% [markdown]
# **Tổng quan bài tập**
#
# Bạn đã được học về hồi quy, một trong những loại học máy quan trọng và có ứng dụng rất nhiều trong cuộc sống. Trong bài tập lớn này, bạn sẽ áp dụng mô hình hồi quy vào bài toán thực tế và áp dụng những kinh nghiệm bạn đã học ở các bài Lab để xây dựng mô hình hồi quy của bạn. Đồng thời bạn sẽ học cách lựa chọn các đặc trưng cho mô hình hồi quy.
#
# **Làm thế nào để hoàn thành?**
#
# 1. **Tải các tệp từ phần Tài nguyên** về kho lưu trữ của bạn (drive hoặc trên máy tính).
#
# 2. Bạn mở tệp notebook bằng Jupyter Notebook, Google Colab hoặc **bất cứ môi trường nào để có thể chạy tệp notebook**.
#
# 3. **Cài đặt các thư viện** cần thiết có trong bài:
# * pandas
# * numpy
# * matplotlib
# * mpl_toolkits
# * sklearn
#
# 4. Đọc và làm theo hướng dẫn có trong notebook. **Điền các khối code trống với code đúng**. Đọc kĩ các nội dung và cố gắng hiểu bài ASM.
#
# **Tài nguyên**
#
# Tải dữ liệu và Jupyter Notebook [tại đây](https://colab.research.google.com/drive/1e_jaoBH8fNHh18Wt_Um228mvh9x4VLwU#scrollTo=c35zRlIJIKok).
#
# Tải file [college.csv](https://drive.google.com/file/d/1MwrrcYAgloXvLPJmnO94RwTrzIiy4XZG/view?usp=drive_link)

# %% [markdown]
# # Hướng dẫn hoàn thành dự án

# %% [markdown]
# Để hoàn thành dự án một cách trơn tru, bạn hãy:
#
# * Cố gắng **hoàn thành tất cả các bài Lab** khi bắt đầu dự án.
# * Bắt đầu và kết thúc bằng cách thực hiện từng nhiệm vụ được liệt kê.
# * Hãy nhớ **trả lời tất cả các câu hỏi bổ sung** trong tệp Notebook. Nếu không, bạn sẽ không đạt đủ điểm.
# * Dự án học máy luôn là một vòng lặp, hãy **thử đi thử lại và lặp đi lặp lại** cho đến khi bạn có kết quả tốt nhất.
# * **Đừng ngần ngại hỏi bất kỳ câu hỏi nào** mà bạn không thể tìm thấy câu trả lời trên google hoặc trong phần gợi ý.
#
# Sẽ **không có một câu trả lời đúng duy nhất** cho mỗi câu hỏi này. Khi thực hiện dự án này, hãy **làm việc nhóm**, tiếp thu các ý kiến nhận xét, đánh giá, từ đó phát triển câu trả lời cho những câu hỏi này.
#
# Để hoàn thành dự án, học viên nên làm theo hướng dẫn chi tiết trong tệp Notebook và hoàn thành tất cả các task cần thiết.
#
# **Task 1. Đọc dữ liệu**
#
# Gợi ý: Sử dụng phương thức read_csv của thư viện Pandas
#
# **Task 2. Mã hóa hạng mục private với phương thức map()**
#
# **Task 3. Trực quan ma trận phương quan**
#
# Tính ma trận trực quan
# Trực quan ma trận bằng seaborn
#
# **Task 4. Trực quan Scatter từng đặc trưng với mục tiêu**
#
# **Task 5. Phân tách dữ liệu đặc trưng vào X, dữ liệu mục tiêu vào y từ dữ liệu gốc**
#
# **Task 6: Tách dữ liệu thành train/test data**
#
# Lưu ý: Dữ liệu train chiếm 70% và random_state là 7.
#
# **Task 7: Mô hình hóa hồi quy tuyến tính chi phí ăn ở và số lượng sinh viên được chấp nhận và trực quan mô hình**
#
# * Tạo dữ liệu train và test.
# * Điều chỉnh hình dạng dữ liệu phù hợp với đầu vào mô hình.
# * Xây dựng và huấn luyện mô hình bằng thư viện Sklearn.
# * Đánh giá chất lượng mô hình trên tập test với chỉ số R2.
# * Trực quan mô hình với dữ liệu test thông qua hàm có sẵn.
#
# **Task 8: Mô hình hóa hồi quy tuyến tính số lượng sinh viên ghi danh cho mỗi trường đại học và số lượng sinh viên được chấp nhận và trực quan mô hình**
#
# Thực hiện tương tự với Task 7
#
# **Task 9: Mô hình hóa hồi quy tuyến tính từng đặc trưng với số lượng sinh viên được chấp nhận và trực quan hóa mô hình với dữ liệu test**
#
# Thực hiện tương tự với Task 7 dựa vào vòng lặp
#
# **Task 10: Mô hình hóa hồi quy tuyến đa biến số lượng sinh viên ghi danh cho mỗi trường đại học và chi phí ăn ở để dự đoán số lượng sinh viên được chấp nhận và trực quan mô hình**
#
# * Thực hiện tương tự với Task 7 nhưng sử dụng 2 đặc trưng thay vì 1 đặc trưng.
# * Trực quan bằng một hàm có sẵn khác phù hợp với 2 đặc trưng.
#
# **Task 11: Sử dụng hồi quy tuyến tính với toàn bộ đặc trưng để quan sát tác động của từng đặc trưng đến mục tiêu**
#
# * Thực hiện tương tự với Task 7 nhưng sử dụng toàn bộ đặc trưng thay vì 1 đặc trưng.
# * Co giãn đặc trưng để mọi đặc trưng đều công bằng.
# * Trả lời câu hỏi.
#
# **Task 12: Xây dựng mô hình hồi quy tuyến tính của riêng bạn**
#
# Yêu cầu: R2 score >= 0.9.
#
# **Task 13: Sử dụng hồi quy Lasso để chọn ra đặc trưng tốt nhất để dự đoán số lượng sinh viên được chấp nhận**
#
# * Yêu cầu: Tìm giá trị alpha sao cho mô hình đạt R2 score >= 9.2.
# * Trả lời câu hỏi.

# %% [markdown]
# # Tiêu chí đánh giá

# %% [markdown]
# **Yêu cầu cơ bản**
#
# | #   | Tiêu chí (Criterion)                                        | Đặc tả (Specification)                                                                 | Trọng số (Weight) | Mandatory | Grading type   |
# |-----|--------------------------------------------------------------|-------------------------------------------------------------------------------------------|-------------------|-----------|----------------|
# | 1   | Có thể đọc dữ liệu từ file                                 | Tải thành công bộ dữ liệu.                                                               | 0.5               | Yes       | Pass/Not Pass |
# | 2   | Chuyển đổi cột Private thành {'Có': 1, 'Không': 0} bằng hàm map | Chuyển đổi thành công bằng hàm map.                                                   | 0.5               | Yes       | Pass/Not Pass |
# | 3   | Trực quan ma trận tương quan cho dữ liệu                    | Trực quan thành công ma trận tương quan cho dữ liệu.                                      | 0.5               | Yes       | Pass/Not Pass |
# | 4   | Trực quan biểu đồ scatter từng đặc trưng với mục tiêu      | Trực quan thành công biểu đồ scatter từng đặc trưng với mục tiêu.                        | 0.5               | Yes       | Pass/Not Pass |
# | 5   | Phân tách dữ liệu đặc trưng vào X, dữ liệu mục tiêu vào y từ dữ liệu gốc | Phân tách thành công dữ liệu đặc trưng vào X, dữ liệu mục tiêu vào y từ dữ liệu gốc. | 0.5               | Yes       | Pass/Not Pass |
# | 6   | Tách dữ liệu thành train/test data                          | Tách thành dữ liệu thành train/test data với train_size = 70% và random_state = 7.       | 0.5               | Yes       | Pass/Not Pass |
# | 7   | Mô hình hóa hồi quy tuyến tính chi phí ăn ở và số lượng sinh viên được chấp nhận | - Tách thành công dữ liệu về chi phí ăn ở từ bộ train và test và lưu vào biến mới.<br>- Định hình lại dữ liệu phù hợp với đầu vào của mô hình. | 0.5               | Yes       | Pass/Not Pass |
# |     |                                                              | Trực quan mô hình hồi quy tuyến tính sử dụng đặc trưng chi phí ăn ở với dữ liệu test.<br>- Xây dựng và huấn luyện mô hình.<br>- Đưa ra kết quả đánh giá R2 mô hình với dữ liệu test.<br>- Trực quan thành công mô hình hồi quy tuyến tính sử dụng đặc trưng chi phí ăn ở với dữ liệu test. |                   |           |                |
# | 8   | Mô hình hóa hồi quy tuyến tính số lượng sinh viên ghi danh cho mỗi trường đại học và số lượng sinh viên được chấp nhận | - Tách thành công dữ liệu số lượng sinh viên ghi danh cho mỗi trường đại học bộ train và test và lưu vào biến mới.<br>- Định hình lại dữ liệu phù hợp với đầu vào của mô hình. | 0.5               | Yes       | Pass/Not Pass |
# |     |                                                              | Trực quan mô hình hồi quy tuyến tính sử dụng đặc trưng số lượng sinh viên ghi danh cho mỗi trường đại học với dữ liệu test.<br>- Xây dựng và huấn luyện mô hình.<br>- Đưa ra kết quả đánh giá R2 mô hình với dữ liệu test.<br>- Trực quan thành công mô hình hồi quy tuyến tính sử dụng đặc trưng số lượng sinh viên ghi danh cho mỗi trường đại học với dữ liệu test. |                   |           |                |
# | 9   | Mô hình hóa hồi quy tuyến tính từng đặc trưng với số lượng sinh viên được chấp nhận và trực quan hóa mô hình | - Tách thành công dữ liệu từng đặc trưng từ bộ train và test và lưu vào biến mới với vòng lặp.<br>- Định hình lại dữ liệu phù hợp với đầu vào của mô hình với vòng lặp.<br>- Xây dựng và huấn luyện mô hình cho từng đặc trưng.<br>- Đưa ra kết quả đánh giá R2 mô hình với dữ liệu test cho từng đặc trưng.<br>- Trực quan mô hình vừa huấn luyện với dữ liệu test cho từng đặc trưng. | 1                 | Yes       | Pass/Not Pass |
# | 10  | Mô hình hóa hồi quy tuyến đa biến số lượng sinh viên ghi danh cho mỗi trường đại học và chi phí ăn ở để dự đoán số lượng sinh viên được chấp nhận | - Tách thành công dữ liệu số lượng sinh viên ghi danh cho mỗi trường đại học và chi phí ăn ở từ bộ train và test và lưu vào biến mới.<br>- Định hình lại dữ liệu phù hợp với đầu vào của mô hình. | 1                 | Yes       | Pass/Not Pass |
# |     |                                                              | Trực quan mô hình hồi quy tuyến tính đa biến sử dụng đặc trưng số lượng sinh viên ghi danh cho mỗi trường đại học và chi phí ăn.<br>- Xây dựng và huấn luyện mô hình.<br>- Đưa ra kết quả đánh giá R2 mô hình với dữ liệu test.<br>- Trực quan thành công mô hình hồi quy tuyến tính đa biến sử dụng đặc trưng số lượng sinh viên ghi danh cho mỗi trường đại học và chi phí ăn. |                   |           |                |
# | 11  | Sử dụng hồi quy tuyến tính với toàn bộ đặc trưng để quan sát tác động của từng đặc trưng đến mục tiêu | - Tạo bản sao dữ liệu đặc trưng từ bộ train và test và lưu vào biến mới.<br>- Định hình lại dữ liệu phù hợp với đầu vào của mô hình.<br>- Co giãn đặc trưng.<br>- Xây dựng và huấn luyện mô hình.<br>- Đưa ra kết quả đánh giá R2 mô hình với dữ liệu test.<br>- Xuất ra kết quả tác động của từng đặc trưng đối với mục tiêu.<br>- Đưa ra kết luận đặc trưng nào tác động nhiều nhất, ít nhất đối với mục tiêu. | 2                 | Yes       | Pass/Not Pass |

# %% [markdown]
# **Yêu cầu nâng cao**

# %% [markdown]
# | #   | Tiêu chí (Criterion)                                        | Đặc tả (Specification)                                                                                                 | Trọng số (Weight) | Mandatory | Grading type   |
# |-----|--------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------|-------------------|-----------|----------------|
# | 12  | Xây dựng mô hình hồi quy tuyến tính của riêng bạn với tùy ý chọn đặc trưng và điều chỉnh siêu tham số | - Xây dựng mô hình hồi quy tuyến tính của riêng bạn thành công với R2 score >= 0.9.<br>- Giải thích quá trình lựa chọn đặc trưng, điều chỉnh tham số để R2 score >= 0.9. | 1                 | Yes       | Scale(0-5)     |
# | 13  | Sử dụng hồi quy Lasso để chọn ra đặc trưng tốt nhất để dự đoán số lượng sinh viên được chấp nhận | - Tìm kiếm giá trị alpha của mô hình Lasso để xây dựng và huấn luyện mô hình sao cho R2 score >= 0.9.<br>- Xuất ra kết quả tác động của từng đặc trưng đối với mục tiêu.<br>- Đưa ra kết luận nhưng đặc trưng nào bị loại bỏ. | 1                 | Yes       | Scale(0-5)     |
